# %%
import matplotlib.pyplot as plt

# Data
companies = ['Eneco Energy(AS40985)*','ABN-Amro(AS15916)**','ING(AS15625)', 'Vitens(AS56517)']
valid_paths = [14, 15, 60, 13]
safe_paths = [0, 0, 20, 3]



# Plotting
plt.figure(figsize=(10, 6))

plt.bar(companies, valid_paths, label='Valid paths', color='blue')  # Plotting total paths
plt.bar(companies, safe_paths, label='100% ROV-protected path', color='green')  # Plotting safe paths as part of total paths

# Adding labels and title
plt.xlabel('Company')
plt.ylabel('Number of Paths')
plt.title('Valid Paths and 100% ROV Paths for AS path length = 3')
plt.legend()
plt.text(2, -15, '* Only one provider with ROV score 0' + '\n'+ '** Out of 2 providers, one has "NA"  score and other has less than 100%',  horizontalalignment = 'center', fontsize=9)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
companies = ['Eneco Energy(AS40985)*','ABN-Amro(AS15916)**','ING(AS15625)', 'Vitens(AS56517)']
valid_paths = [3, 5, 17, 3]
safe_paths = [0, 0, 8, 1]



# Plotting
plt.figure(figsize=(10, 6))

plt.bar(companies, valid_paths, label='Valid paths', color='blue')  # Plotting total paths
plt.bar(companies, safe_paths, label='100% ROV-protected path', color='green')  # Plotting safe paths as part of total paths

# Adding labels and title
plt.xlabel('Company')
plt.ylabel('Number of Paths')
plt.title('Valid Paths and 100% ROV Paths for AS path length = 2')
plt.legend()
plt.text(2, -3, '* Only one provider with ROV score 0' + '\n'+ '** Out of 2 providers, one has "NA"  score and other has less than 100%',  horizontalalignment = 'center', fontsize=9)

plt.show()

# %%
# For AS15625
import matplotlib.pyplot as plt
import numpy as np

# Globally update the font size
plt.rcParams.update({'font.size': 18})

    
x = [1,2,3,4]
total_paths_y = [0, 47, 710, 8192]
valid_paths_y = [0, 17, 60, 85]

hundred_rov_y = [0, 8, 12,0]
zero_rov_y = [0, 9, 27, 4]
na_rov_y = [0, 0, 3, 20]
ninety_rov_y = [0, 0, 1, 1]


# plt.figure(figsize=(4, 3))  # Set the figure size to 4 inches wide and 3 inches tall

# Plot
plt.plot(x, valid_paths_y,'-o', label='valid')
plt.plot(x, na_rov_y, '-o', label='NA ROV')
plt.plot(x, hundred_rov_y, '-o', label='100% ROV')

plt.plot(x, zero_rov_y, '-o', label='0% ROV')

# plt.plot(x, ninety_rov_y, '-o',label='(90-99)% ROV') # For average ROV score
plt.plot(x, ninety_rov_y, '-o',label='(90-95)% ROV')


plt.xlabel("No. of AS hops", fontsize=18)
plt.ylabel("No. of paths", fontsize=18)
# plt.title('No. of AS hops vs no. of paths for AS15625')
plt.xticks(x, x, fontsize=16)
# plt.yticks(y, x, fontsize=16)


plt.legend()
plt.legend().get_frame().set_facecolor('none')

#plt.legend(fontsize=16) # using a size in points
plt.savefig("/home/shyam/Downloads/AS15625_2.pdf", bbox_inches='tight')

plt.show()

# %%
# For AS56517
import matplotlib.pyplot as plt
import numpy as np


plt.rcParams.update({'font.size': 18})

x = [1,2,3,4]
valid_paths_y = [0, 3, 10, 0]

hundred_rov_y = [0, 1, 2, 0]
zero_rov_y = [0, 2, 8, 0]
na_rov_y = [0, 0, 0, 0]
ninety_rov_y = [0, 0, 0, 0]

# plt.figure(figsize=(4, 3))

# Plot
plt.plot(x, valid_paths_y,'-o', label='valid')
plt.plot(x, na_rov_y, '-o', label='NA ROV')
plt.plot(x, hundred_rov_y, '-o', label='100% ROV')

plt.plot(x, zero_rov_y, '-o', label='0% ROV')

#plt.plot(x, ninety_rov_y, '-^',label='(90-99)% ROV')


plt.xlabel("No. of AS hops")
plt.ylabel("No. of paths")
# plt.title('No. of AS hops vs no. of paths for AS56517')
plt.xticks(x, x)


plt.legend()
plt.legend().get_frame().set_facecolor('none')

plt.savefig("/home/shyam/Downloads/AS56517.pdf", bbox_inches='tight')

plt.show()

# %%
# For AS40985
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({'font.size': 18})

x = [1,2,3,4]
valid_paths_y = [1, 2, 11,0]

hundred_rov_y = [0, 0, 0, 0]
zero_rov_y = [1, 2, 11, 0]
na_rov_y = [0, 0, 0, 0]
ninety_rov_y = [0, 0, 0, 0]
provider_implement_rov_y= [1, 2, 11, 0]

# plt.figure(figsize=(4, 3))

# Plot
plt.plot(x, valid_paths_y,'-o', label='valid')
plt.plot(x, na_rov_y, '-o', label='NA ROV')
plt.plot(x, hundred_rov_y, '-o', label='100% ROV')

plt.plot(x, zero_rov_y, '-o', label='0% ROV')

# plt.plot(x, ninety_rov_y, '-o',label='(90-99)% ROV')

plt.plot(x, provider_implement_rov_y, '-o',label='if provider \n does full \n ROV')

plt.xlabel("No. of AS hops")
plt.ylabel("No. of paths")
# plt.title('No. of AS hops vs no. of paths for AS40985*')
plt.xticks(x, x)


plt.legend()
plt.legend().get_frame().set_facecolor('none')

plt.savefig("/home/shyam/Downloads/AS40985.pdf", bbox_inches='tight')

plt.show()

# %%
# For AS15916
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({'font.size': 18})

x = [1,2,3,4]
valid_paths_y = [0, 5, 10, 5]

hundred_rov_y = [0, 0, 0, 0]
ninety_rov_y = [0, 5, 4, 0]
zero_rov_y = [0, 0, 1, 0]
na_rov_y = [0, 0, 5, 5]


# Plot
plt.plot(x, valid_paths_y,'-o', label='valid')
plt.plot(x, na_rov_y, '-o', label='NA ROV')
plt.plot(x, hundred_rov_y, '-o', label='100% ROV')

plt.plot(x, zero_rov_y, '-o', label='0% ROV')

# plt.plot(x, ninety_rov_y, '-o',label='~90% \n ROV') # For average ROV score
plt.plot(x, ninety_rov_y, '-o',label='~60% \n ROV') # For minimum ROV score




plt.xlabel("No. of AS hops")
plt.ylabel("No. of paths")
# plt.title('No. of paths vs path length for AS15916*')
plt.xticks(x, x)


plt.legend()
# plt.legend(frameon=False)
#Background white
plt.legend().get_frame().set_facecolor('none')

plt.savefig("/home/shyam/Downloads/AS15916.pdf", bbox_inches='tight')

plt.show()
